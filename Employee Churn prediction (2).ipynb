# %%
import sklearn
sklearn.__version__
# Out:
# '0.23.1'

# %% [markdown]
# ### import the important modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import the data and read it
df = pd.read_csv("C:/Users/anjali suryawanshi/Desktop/hr_data.csv")

# %%
df.head()  #Show first five rows of the dataset
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %% [markdown]
# ##### After you have loaded the dataset, you might want to know a little bit more about it. You can check attriutes names and datatypes using info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# ##### The describe() function in pandas is very handy in getting various summary statistics.This function returns the count, mean, standard deviation, minimum and maximum values and the quantiles of the data.

# %%
df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years
# count   14999.000000  14999.000000           14999.000000
# mean        0.144610      0.238083               0.021268
# std         0.351719      0.425924               0.144281
# ...

# %%
#get unique department name
df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
#load statisfication data of employee
df_1 = pd.read_excel("C:/Users/anjali suryawanshi/Desktop/employee_satisfaction_evaluation.xlsx")

# %%
df_1.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
#merge and join the above two df
main_df = df.set_index('employee_id').join(df_1.set_index('EMPLOYEE #'))

# %%
main_df.head()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# employee_id
# 1003                      2                   157                   3
# 1005                      5                   262                   6
# 1486                      7                   272                   4
# 1038                      5                   223                   5
# 1057                      2                   159                   3
#
#              Work_accident  left  promotion_last_5years department  salary  \
# employee_id
# 1003                     0     1                      0      sales     low
# 1005                     0     1                      0      sales  medium
# 1486                     0     1                      0      sales  medium
# 1038                     0     1                      0      sales     low
# 1057                     0     1                      0      sales     low
#
#              satisfaction_level  last_evaluation
# employee_id
# ...

# %%
main_df=main_df.reset_index() ##reset the index

# %%
main_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
 main_df[main_df.isnull().any(axis=1)]  #see the Null value that in which cloumn we have null values
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# ...

# %% [markdown]
# #### The describe() function in pandas is very handy in getting various summary statistics.This function returns the count, mean, standard deviation, minimum and maximum values and the quantiles of the data

# %%
main_df.describe() ##main dataframe after merge of both the dataframe
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# ...

# %%
#fill the nullvalue with mean of the dataframe 
main_df.fillna(main_df.mean(),inplace=True)

# %%
#after filling null values check the dataset
main_df[main_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary, satisfaction_level, last_evaluation]
# Index: []

# %%
#check whether it fill the mean value or not
main_df.loc[main_df['employee_id']==3794]
# Out:
#     employee_id  number_project  average_montly_hours  time_spend_company  \
# 18         3794               2                   160                   3
#
#     Work_accident  left  promotion_last_5years department salary  \
# 18              1     1                      1      sales    low
#
#     satisfaction_level  last_evaluation
# 18             0.61283         0.716125

# %%
#drop employee id
main_df.drop(columns='employee_id',inplace=True)

# %%
main_df.head()
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
# 3               5                   223                   5              0
# 4               2                   159                   3              0
#
#    left  promotion_last_5years department  salary  satisfaction_level  \
# 0     1                      0      sales     low                0.38
# 1     1                      0      sales  medium                0.80
# 2     1                      0      sales  medium                0.11
# 3     1                      0      sales     low                0.72
# 4     1                      0      sales     low                0.37
#
#    last_evaluation
# 0             0.53
# 1             0.86
# 2             0.88
# ...

# %% [markdown]
# #### now we can find the sum of every  cloumn with respect to each department using groupby() and sum() function,here we can intrepret the total no.of project done by each department,total avg_mon_hours spent by employees in each department ,total time spent in company  by each department and many more like this

# %%
main_df.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# ...

# %% [markdown]
# #### Here we find the average of every cloumn with respect to the department using groupby() and mean() function

# %%
main_df.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# ...

# %% [markdown]
# ###### we intrepret this that average num of project done by IT department is 3.816626 ,the avg time_spend_company of this department is 3.468623,avg work_accident is 0.133659 and like this for all columns and department

# %%
main_df['left'].value_counts() ##it show how many employee left the company by 1 and  not left the company by 0
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %% [markdown]
# ###  Data visualization

# %%
import seaborn as sns
# Out:
# C:\Users\anjali suryawanshi\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ######  see the  correlation between each independent variable ,which interpret weather the independent varibale is positively correlated or negatively correlated or it' highly correlated,remember that  when the two independent vairibale is highly correlated then it's issue of multicollinearity.

# %%
main_df.corr()
# Out:
#                        number_project  average_montly_hours  \
# number_project               1.000000              0.417211
# average_montly_hours         0.417211              1.000000
# time_spend_company           0.196786              0.127755
# Work_accident               -0.004741             -0.010143
# left                         0.023787              0.071287
# promotion_last_5years       -0.006064             -0.003544
# satisfaction_level          -0.143895             -0.020886
# last_evaluation              0.348776              0.339014
#
#                        time_spend_company  Work_accident      left  \
# number_project                   0.196786      -0.004741  0.023787
# average_montly_hours             0.127755      -0.010143  0.071287
# time_spend_company               1.000000       0.002120  0.144822
# Work_accident                    0.002120       1.000000 -0.154622
# left                             0.144822      -0.154622  1.000000
# ...

# %%
plt.figure(figsize=(12,10))                     ####Through visualization
sns.heatmap(main_df.corr(),annot=True,cmap="YlGnBu")

# %%
# grph between left and satisfactin_level
sns.barplot(x='left',y='satisfaction_level',data=main_df)

# %% [markdown]
#  ###### we can intrepret the above plot that ,the employee who stay in the company has high satisfaction level and the employee who left the company has low satisfication level

# %%
#check satisfication level and promotion year and how many left
sns.barplot(x='promotion_last_5years',y='satisfaction_level',data=main_df,hue='left')

# %% [markdown]
# ##### we can interpret the above plot is  that ,the employees who didn't get any promotion from the last 5 year and also didn't left the company has high satisfication level instead of  that employee who didin't get the promotion but left the company has low satisfication level,on other side the employee who get the promotion and stay in the company has high satisfaction level instead of the employee who get the promotion but leave the company has low satisfication level.

# %%
sns.pairplot(main_df,hue='left')
# Out:
# C:\Users\anjali suryawanshi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\anjali suryawanshi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\anjali suryawanshi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\anjali suryawanshi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# #####  Lots of machine learning algorithms require numerical input data, so you need to represent categorical columns in a numerical column.
# In order to encode this data, you could map each value to a number.
#
# This process is known as label encoding, and sklearn conveniently will do this for you using LabelEncoder

# %%
main_df[['department','salary']]
# Out:
#       department  salary
# 0          sales     low
# 1          sales  medium
# 2          sales  medium
# 3          sales     low
# 4          sales     low
# ...          ...     ...
# 14994    support     low
# 14995    support     low
# 14996    support     low
# 14997    support     low
# 14998    support     low
#
# [14999 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
le1 = LabelEncoder()                                ### encode salary 
main_df['salary'] = le.fit_transform(main_df.salary)

# %%
main_df.head()
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
# 3               5                   223                   5              0
# 4               2                   159                   3              0
#
#    left  promotion_last_5years department  salary  satisfaction_level  \
# 0     1                      0      sales       1                0.38
# 1     1                      0      sales       2                0.80
# 2     1                      0      sales       2                0.11
# 3     1                      0      sales       1                0.72
# 4     1                      0      sales       1                0.37
#
#    last_evaluation
# 0             0.53
# 1             0.86
# 2             0.88
# ...

# %%
main_df['department'] = le1.fit_transform(main_df.department)  ## encode department

# %%
main_df.head()
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
# 3               5                   223                   5              0
# 4               2                   159                   3              0
#
#    left  promotion_last_5years  department  salary  satisfaction_level  \
# 0     1                      0           7       1                0.38
# 1     1                      0           7       2                0.80
# 2     1                      0           7       2                0.11
# 3     1                      0           7       1                0.72
# 4     1                      0           7       1                0.37
#
#    last_evaluation
# 0             0.53
# 1             0.86
# 2             0.88
# ...

# %%
main_df['department'].unique()
# Out:
# array([7, 2, 3, 9, 8, 4, 0, 6, 5, 1])

# %%
le1.inverse_transform([7, 2, 3, 9, 8, 4, 0, 6, 5, 1])  ## the number asign to each attribute in the department column
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
main_df['salary'].unique()
# Out:
# array([1, 2, 0])

# %%
le.inverse_transform([1,2,0]) ## nymber assign to each attribute in salary column
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
x = main_df.drop(['left'],axis=1)  ## for X label we drop the left from the column

# %%
y = main_df['left'] ## y label

# %% [markdown]
# #####   To understand model performance, dividing the dataset into a training set and a test set is a good strategy.
#
# Let's split dataset by using function train_test_split(). you need to pass basically 3 parameters features, target, and test_set size. Additionally, you can use random_state to select records randomly

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.30,random_state=0)

# %%
x_test
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 1670                2                   141                   3
# 13378               3                   194                   3
# 10233               5                   210                   2
# 4719                4                   177                   2
# 7003                3                   198                   3
# ...               ...                   ...                 ...
# 11275               3                   211                   6
# 3828                5                   262                   2
# 4645                4                   273                   4
# 6069                6                   278                   2
# 2506                4                   171                   5
#
#        Work_accident  promotion_last_5years  department  salary  \
# 1670               0                      0           6       2
# 13378              0                      0           6       2
# ...

# %%
y_test
# Out:
# 1670     1
# 13378    0
# 10233    0
# 4719     0
# 7003     0
#         ..
# 11275    0
# 3828     0
# 4645     0
# 6069     0
# 2506     0
# Name: left, Length: 4500, dtype: int64

# %%
x_train.shape
# Out:
# (10499, 9)

# %%
x_test.shape
# Out:
# (4500, 9)

# %% [markdown]
# ##### Let's build employee churn prediction model.
#
# Here, you are going to predict churn using Decision Tree Classifier.
#
# First, import the Decision TreeClassifier module and create object using Decision TreeClassifier() function.
#
# Then, fit your model on train set using fit() and perform prediction on the test set using predict()

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)   ## predict  on the test data

# %%
from sklearn.metrics import accuracy_score     ## Accuracy of the model 
accuracy_score(y_test,y_pred)*100
# Out:
# 97.39999999999999

# %% [markdown]
# ### Post pruning decison tree with cost complexity pruning

# %%
from sklearn import tree
plt.figure(figsize=(25,10))
tree.plot_tree(dt,filled=True)
# Out:
# [Text(635.3262019502945, 530.6571428571428, 'X[7] <= 0.465\ngini = 0.366\nsamples = 10499\nvalue = [7966, 2533]'),
#  Text(212.3528079710145, 504.7714285714286, 'X[0] <= 2.5\ngini = 0.475\nsamples = 2920\nvalue = [1136, 1784]'),
#  Text(47.173913043478265, 478.8857142857143, 'X[8] <= 0.575\ngini = 0.218\nsamples = 1224\nvalue = [152, 1072]'),
#  Text(26.956521739130437, 453.0, 'X[8] <= 0.445\ngini = 0.105\nsamples = 1130\nvalue = [63, 1067]'),
#  Text(22.46376811594203, 427.11428571428576, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(31.449275362318843, 427.11428571428576, 'X[1] <= 162.0\ngini = 0.055\nsamples = 1098\nvalue = [31, 1067]'),
#  Text(17.971014492753625, 401.22857142857146, 'X[1] <= 125.5\ngini = 0.029\nsamples = 1078\nvalue = [16, 1062]'),
#  Text(13.478260869565219, 375.34285714285716, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(22.46376811594203, 375.34285714285716, 'X[7] <= 0.34\ngini = 0.011\nsamples = 1068\nvalue = [6, 1062]'),
# ...

# %%
path = dt.cost_complexity_pruning_path(x_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
ccp_alphas
# Out:
# array([0.00000000e+00, 3.80211138e-05, 3.80587625e-05, 4.73951727e-05,
#        4.73989437e-05, 4.75973732e-05, 5.99704381e-05, 6.13085209e-05,
#        6.15137950e-05, 6.15137950e-05, 6.25909951e-05, 6.26400284e-05,
#        6.31407107e-05, 6.33176361e-05, 6.33993580e-05, 6.34849356e-05,
#        7.26157446e-05, 7.32431271e-05, 7.36147591e-05, 7.52107879e-05,
#        7.52741242e-05, 7.56534636e-05, 7.95260226e-05, 8.33412706e-05,
#        8.46641479e-05, 8.57224498e-05, 8.73099025e-05, 8.79266494e-05,
#        8.92942185e-05, 8.96443919e-05, 8.96443919e-05, 8.98981407e-05,
#        9.04848081e-05, 9.17194936e-05, 9.20722609e-05, 9.30824581e-05,
#        9.44330881e-05, 9.48117188e-05, 9.49020680e-05, 9.52471664e-05,
#        9.52471664e-05, 9.52471664e-05, 9.59667321e-05, 1.08889247e-04,
#        1.09840142e-04, 1.11336096e-04, 1.12850689e-04, 1.19709169e-04,
#        1.22015978e-04, 1.26031642e-04, 1.26364591e-04, 1.26996222e-04,
# ...

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(x_train, y_train)
    clfs.append(clf)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      clfs[-1].tree_.node_count, ccp_alphas[-1]))
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.10531609478592185

# %%
train_scores = [clf.score(x_train, y_train) for clf in clfs]
test_scores = [clf.score(x_test, y_test) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %%
clf = DecisionTreeClassifier(random_state=0, ccp_alpha=0.015)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.015, random_state=0)

# %%
pred=clf.predict(x_test)
from sklearn.metrics import accuracy_score
Dct_acc=accuracy_score(y_test, pred)
Dct_acc
# Out:
# 0.9566666666666667

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(334.8, 489.24, 'X[7] <= 0.465\ngini = 0.366\nsamples = 10499\nvalue = [7966, 2533]'),
#  Text(167.4, 380.52000000000004, 'X[0] <= 2.5\ngini = 0.475\nsamples = 2920\nvalue = [1136, 1784]'),
#  Text(83.7, 271.8, 'gini = 0.218\nsamples = 1224\nvalue = [152, 1072]'),
#  Text(251.10000000000002, 271.8, 'X[7] <= 0.115\ngini = 0.487\nsamples = 1696\nvalue = [984, 712]'),
#  Text(167.4, 163.08000000000004, 'gini = 0.0\nsamples = 629\nvalue = [0, 629]'),
#  Text(334.8, 163.08000000000004, 'gini = 0.143\nsamples = 1067\nvalue = [984, 83]'),
#  Text(502.20000000000005, 380.52000000000004, 'X[2] <= 4.5\ngini = 0.178\nsamples = 7579\nvalue = [6830, 749]'),
#  Text(418.5, 271.8, 'gini = 0.032\nsamples = 6193\nvalue = [6091, 102]'),
#  Text(585.9, 271.8, 'X[8] <= 0.815\ngini = 0.498\nsamples = 1386\nvalue = [739, 647]'),
#  Text(502.20000000000005, 163.08000000000004, 'gini = 0.102\nsamples = 537\nvalue = [508, 29]'),
# ...

# %%
from sklearn.model_selection import cross_val_score  ## cross validation score
scores = cross_val_score(clf,x,y,cv=10)

# %%
scores
# Out:
# array([0.95933333, 0.96333333, 0.952     , 0.96266667, 0.95533333,
#        0.95533333, 0.96066667, 0.95866667, 0.91      , 0.90593729])

# %%
clf_acc=scores.mean()
clf_acc                        ## Accuracy of the model through cross validation score
# Out:
# 0.9483270624861019

# %%
#see which feature  is how much important in predition
clf.feature_importances_
# Out:
# array([0.09847956, 0.05650142, 0.1530087 , 0.        , 0.        ,
#        0.        , 0.        , 0.59249139, 0.09951892])

# %%
feature_importence_ = pd.DataFrame(clf.feature_importances_,index=x_train.columns,columns=['importance']).sort_values('importance',ascending=False)

# %%
feature_importence_
# Out:
#                        importance
# satisfaction_level       0.592491
# time_spend_company       0.153009
# last_evaluation          0.099519
# number_project           0.098480
# average_montly_hours     0.056501
# Work_accident            0.000000
# promotion_last_5years    0.000000
# department               0.000000
# salary                   0.000000

# %% [markdown]
# ### Data preprocessing for knn

# %% [markdown]
# ##### In this cell we will do standard scaling to normalize the data,The Standard Scaler assumes data is normally distributed within each feature and scales them such that the distribution centered around 0, with a standard deviation of 1

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler().fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
x_train_std
# Out:
# array([[-1.4550047 , -1.32687641,  0.34783914, ...,  1.04154145,
#         -0.33339188, -1.1594319 ],
#        [ 0.96656904,  1.10125206, -0.34290478, ...,  1.04154145,
#          0.63440935, -1.1007587 ],
#        [-0.64781345, -1.04593592, -1.0336487 , ...,  1.04154145,
#          1.11830996,  0.42474454],
#        ...,
#        [ 0.96656904,  1.1614536 , -1.0336487 , ...,  1.04154145,
#          0.31180894,  1.30484256],
#        [ 0.96656904,  0.69990852, -0.34290478, ..., -2.1577399 ,
#          0.6747344 , -0.74871949],
#        [ 0.96656904,  0.03769166, -1.0336487 , ..., -0.55809923,
#         -0.21241673, -0.22066068]])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train_std,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_prd = knn.predict(x_test_std)

# %%
accuracy_score(y_test,y_prd)*100
# Out:
# 95.64444444444445

# %%
score = cross_val_score(knn,x,y,cv=10)

# %%
knn_acc=score.mean()
knn_acc
# Out:
# 0.9453314209472982

# %% [markdown]
# ##### now in this line we will run a loop to choose the perfect nearest neighbors and fit the train data and predict on test data

# %%
from sklearn.metrics import accuracy_score
knn_score = []

for k in range(1,21):
    

    knn= KNeighborsClassifier(n_neighbors=k)

    score = knn.fit(x_train_std,y_train)

    y_predt = knn.predict(x_test_std)
    
    
    knn_score.append(accuracy_score(y_test,y_predt))

# %%
knn_score
# Out:
# [0.9684444444444444,
#  0.9646666666666667,
#  0.9564444444444444,
#  0.9595555555555556,
#  0.9533333333333334,
#  0.956,
#  0.9504444444444444,
#  0.954,
#  0.9504444444444444,
#  0.9524444444444444,
#  0.9491111111111111,
#  0.9491111111111111,
#  0.9477777777777778,
#  0.9491111111111111,
#  0.9462222222222222,
#  0.9468888888888889,
#  0.944,
#  0.9453333333333334,
#  0.9422222222222222,
#  0.9431111111111111]

# %%
from matplotlib import rcParams
plt.rcParams['figure.figsize']=(20,10)
plt.plot([k for k in range(1, 21)], knn_score, color = 'red')
for i in range(1,21):
    plt.text(i, knn_score[i-1], (i, knn_score[i-1]))
plt.xticks([i for i in range(1, 21)])
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Scores')
plt.title('K Neighbors Classifier scores for different K values')
# Out:
# Text(0.5, 1.0, 'K Neighbors Classifier scores for different K values')

# %%
knn= KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train_std,y_train)
y_predt = knn.predict(x_test_std)
accuracy_score(y_test,y_predt)*100
# Out:
# 95.64444444444445

# %%
#from cross validation score
from sklearn.model_selection import cross_val_score 
knn_score = []
for k in range(1,21):
    knn = KNeighborsClassifier(n_neighbors=k)
    score = cross_val_score(knn,x,y,cv=10)
    knn_score.append(score.mean())

# %%
plt.plot([k for k in range(1, 21)], knn_score, color = 'red')
for i in range(1,21):
    plt.text(i, knn_score[i-1], (i, knn_score[i-1]))
plt.xticks([i for i in range(1, 21)])
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Scores')
plt.title('K Neighbors Classifier scores for different K values')
# Out:
# Text(0.5, 1.0, 'K Neighbors Classifier scores for different K values')

# %%
knn= KNeighborsClassifier(n_neighbors=3)
score = cross_val_score(knn,x,y,cv=10)
knn_acc=score.mean()
knn_acc
# Out:
# 0.9453314209472982

# %%
plt.rcParams['figure.figsize']=(5,5)
algorithms=['Decision Tree','KNN']
scores=[clf_acc,knn_acc]                              ## see which alogrithm give us a better result through visualization
plt.xlabel("Algorithms")
plt.ylabel("Accuracy Score")
sns.barplot(algorithms,scores)
plt.show()

# %%
Catagory=['Employee will stay','Employee will Leave']
custom_dt=[[1,500,3,6,0,0.90,0.89,1,8]]

# %%
print(int(clf.predict(custom_dt)))
# Out:
# 0

# %%
Catagory[int(clf.predict(custom_dt))]
# Out:
# 'Employee will stay'

# %% [markdown]
# #### A confusion matrix is a table that is often used to describe the performance of a classification model (or “classifier”) on a set of test data for which the true values are known. It allows the visualization of the performance of an algorithm

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
con = confusion_matrix(y_test,y_pred)

# %%
con
# Out:
# array([[3380,   82],
#        [  35, 1003]], dtype=int64)

# %%
print(classification_report(y_test,pred))  ## classification report of decision tree algorithm
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3462
#            1       0.90      0.91      0.91      1038
#
#     accuracy                           0.96      4500
#    macro avg       0.94      0.94      0.94      4500
# weighted avg       0.96      0.96      0.96      4500

# %% [markdown]
# #### Well, you got a classification rate of 96%, considered as good accuracy.
#
# Precision: Precision is about being precise i.e. How precise your model is. In other words, you can say, when a model makes a prediction, how often it is correct. In your prediction case, when your Decision Tree model predicted an employee is going to leave, that employee actually left 90% time.
#
# Recall: If there is an employee who actually left present in the test set and your Decision Tree model is able to identify it 91% of the time

# %%
print(classification_report(y_test,y_predt))  ## classification report of KNN
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      3462
#            1       0.88      0.93      0.91      1038
#
#     accuracy                           0.96      4500
#    macro avg       0.93      0.95      0.94      4500
# weighted avg       0.96      0.96      0.96      4500
